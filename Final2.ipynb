# %% [markdown]
# <a href="https://colab.research.google.com/github/OrtegaJulio7/SIS420/blob/main/Final2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reinforcement learning (Aprendizaje por refuerzo)
#
# El aprendizaje por refuerzo (RL) es una técnica de machine learning (ML) que entrena al software para que tome decisiones a fin de lograr los mejores resultados. Imita el proceso de aprendizaje por ensayo y error que los humanos utilizan para lograr sus objetivos.
# <HR>
#  <h3>
#   NOMBRE:
#   * ORTEGA ALBARADO JULIO CESAR<br>
#
#   CARRERA: INGENIERIA DE SISTEMAS <BR>
#
#   * [Enlace al git hub](https://github.com/OrtegaJulio7/SIS420/blob/main/Final.ipynb)
#
#  <h3>

# %% [markdown]
# # Descripcion del proyecto:Juego de Navegación con Q-learning en un Entorno Dinámico
# El proyecto tiene como objetivo crear un juego de navegación en el que un agente(prisionero) aprende a moverse en un entorno dinámico utilizando el algoritmo de Q-learning, una técnica de aprendizaje por refuerzo. El entorno está diseñado para ser desafiante, con obstáculos, trampas y un guardia que persigue al agente, haciendo que el agente tenga que tomar decisiones inteligentes para lograr escapar o alcanzar una meta (la salida) sin ser atrapado.

# %% [markdown]
# ## Entorno del Juego
# * El entorno es una cuadrícula de 5x5 (puede ser ampliado según se desee).
# * El agente puede moverse en 4 direcciones: arriba, abajo, izquierda y derecha.
# * Las posiciones de la trampa, el guardia y la salida se generan aleatoriamente al inicio de cada episodio.
# * El guardia se mueve aleatoriamente dentro del entorno, representando un peligro para el agente.
# * El agente obtiene una recompensa positiva por alcanzar la salida y penalizaciones por caer en la trampa o ser atrapado por el guardia.

# %% [markdown]
# # 1. Crear el entorno dinámico

# %%
import random
import numpy as np

# Definir el tamaño del entorno (por ejemplo, una cuadrícula 5x5)
tamaño = (5, 5)

# Definir posiciones especiales
def generar_posiciones_dinamicas():
    """
    Genera posiciones aleatorias para los obstáculos, el guardia y la salida en el entorno.
    """
    trampa = (random.randint(0, tamaño[0]-1), random.randint(0, tamaño[1]-1))
    guardia = (random.randint(0, tamaño[0]-1), random.randint(0, tamaño[1]-1))

    while trampa == guardia:  # Asegurarse de que no haya superposición entre trampa y guardia
        guardia = (random.randint(0, tamaño[0]-1), random.randint(0, tamaño[1]-1))

    salida = (random.randint(0, tamaño[0]-1), random.randint(0, tamaño[1]-1))

    return trampa, guardia, salida

def mover_guardia(guardia):
    """
    Mueve el guardia aleatoriamente en el entorno.
    """
    mov = random.choice([(0, 1), (0, -1), (1, 0), (-1, 0)])  # Movimiento aleatorio
    nueva_pos = (guardia[0] + mov[0], guardia[1] + mov[1])
    nueva_pos = (max(0, min(nueva_pos[0], tamaño[0]-1)), max(0, min(nueva_pos[1], tamaño[1]-1)))  # Asegurarse que no salga del entorno
    return nueva_pos

def obtener_recompensa(estado, guardia, trampa, salida):
    """
    Calcula la recompensa en función de la ubicación del agente.
    """
    if estado == salida:
        return 100  # Recompensa por llegar a la salida
    elif estado == trampa:
        return -50  # Penalización por caer en la trampa
    elif estado == guardia:
        return -20  # Penalización por encontrarse con el guardia
    else:
        return -1  # Penalización por moverse a cualquier otro estado (costo de movimiento)

# %% [markdown]
# # 2. Implementación de Q-learning con entorno dinámico
# Implementamos el algoritmo de Q-learning, donde el agente aprenderá a tomar decisiones basadas en la tabla Q. El entorno es dinámico y cambiará a medida que el agente avanza.

# %%
# Inicialización de la tabla Q (por ejemplo, para una cuadrícula 5x5)
Q = np.zeros((tamaño[0], tamaño[1], 4))  # 4 acciones: arriba, abajo, izquierda, derecha

# Parámetros de Q-learning
alpha = 0.1  # Tasa de aprendizaje
gamma = 0.9  # Factor de descuento
epsilon = 0.3  # Tasa de exploración
n_episodios = 500  # Número de episodios de entrenamiento

# Definir las acciones (0: Arriba, 1: Abajo, 2: Izquierda, 3: Derecha)
acciones = [(0, 1), (0, -1), (-1, 0), (1, 0)]  # Movimiento en (fila, columna)

# Función para seleccionar acción (exploración o explotación) E-greedy
def seleccionar_accion(estado):
    if random.uniform(0, 1) < epsilon:  # Exploración
        return random.choice([0, 1, 2, 3])  # Seleccionar una acción aleatoria
    else:  # Explotación
        return np.argmax(Q[estado[0], estado[1]])  # Elegir la acción con mayor valor Q

# Función para actualizar la tabla Q
def actualizar_Q(estado, accion, recompensa, nuevo_estado):
    # Q-Update Rule: Q(s, a) <- Q(s, a) + alpha * (recompensa + gamma * max(Q(s', a)) - Q(s, a))
    max_Q = np.max(Q[nuevo_estado[0], nuevo_estado[1]])  # Mejor valor Q del siguiente estado
    Q[estado[0], estado[1], accion] += alpha * (recompensa + gamma * max_Q - Q[estado[0], estado[1], accion])

# Función para entrenar al agente en el entorno dinámico
def entrenar_agente():
    for episodio in range(n_episodios):
        # Inicializar el entorno dinámicamente en cada episodio
        trampa, guardia, salida = generar_posiciones_dinamicas()
        estado = (random.randint(0, tamaño[0]-1), random.randint(0, tamaño[1]-1))  # Estado inicial aleatorio

        total_recompensa = 0
        pasos = 0

        while estado != salida and pasos < 50:  # Limitar el número de pasos para evitar bucles infinitos
            accion = seleccionar_accion(estado)  # Elegir una acción
            nuevo_estado = (estado[0] + acciones[accion][0], estado[1] + acciones[accion][1])

            # Asegurarse de que el nuevo estado esté dentro de los límites del entorno
            nuevo_estado = (max(0, min(nuevo_estado[0], tamaño[0]-1)), max(0, min(nuevo_estado[1], tamaño[1]-1)))

            # Obtener recompensa dinámica
            recompensa = obtener_recompensa(nuevo_estado, guardia, trampa, salida)

            # Actualizar la tabla Q
            actualizar_Q(estado, accion, recompensa, nuevo_estado)

            # Mover al guardia y actualizar la recompensa
            guardia = mover_guardia(guardia)

            # Pasar al siguiente estado
            estado = nuevo_estado
            total_recompensa += recompensa
            pasos += 1

        print(f"Episodio {episodio + 1}/{n_episodios} - Recompensa total: {total_recompensa}")

# Entrenamiento del agente
entrenar_agente()
# Out:
# Episodio 1/500 - Recompensa total: -167
# Episodio 2/500 - Recompensa total: -107
# Episodio 3/500 - Recompensa total: -126
# Episodio 4/500 - Recompensa total: 75
# Episodio 5/500 - Recompensa total: -156
# Episodio 6/500 - Recompensa total: -69
# Episodio 7/500 - Recompensa total: -118
# Episodio 8/500 - Recompensa total: -88
# Episodio 9/500 - Recompensa total: -107
# Episodio 10/500 - Recompensa total: 92
# Episodio 11/500 - Recompensa total: -50
# Episodio 12/500 - Recompensa total: -69
# Episodio 13/500 - Recompensa total: -69
# Episodio 14/500 - Recompensa total: -167
# Episodio 15/500 - Recompensa total: -197
# Episodio 16/500 - Recompensa total: -99
# Episodio 17/500 - Recompensa total: 99
# Episodio 18/500 - Recompensa total: -25
# Episodio 19/500 - Recompensa total: 79
# Episodio 20/500 - Recompensa total: -107
# Episodio 21/500 - Recompensa total: -85
# Episodio 22/500 - Recompensa total: 0
# Episodio 23/500 - Recompensa total: -167
# Episodio 24/500 - Recompensa total: 69
# Episodio 25/500 - Recompensa total: 3
# Episodio 26/500 - Recompensa total: 96
# Episodio 27/500 - Recompensa total: 28
# Episodio 28/500 - Recompensa total: -88
# Episodio 29/500 - Recompensa total: 76
# Episodio 30/500 - Recompensa total: 61
# Episodio 31/500 - Recompensa total: -330
# Episodio 32/500 - Recompensa total: 56
# Episodio 33/500 - Recompensa total: 52
# Episodio 34/500 - Recompensa total: 94
# Episodio 35/500 - Recompensa total: -164
# Episodio 36/500 - Recompensa total: 36
# Episodio 37/500 - Recompensa total: -32
# Episodio 38/500 - Recompensa total: -137
# Episodio 39/500 - Recompensa total: 96
# Episodio 40/500 - Recompensa total: 0
# Episodio 41/500 - Recompensa total: 97
# Episodio 42/500 - Recompensa total: -107
# Episodio 43/500 - Recompensa total: -118
# Episodio 44/500 - Recompensa total: 75
# Episodio 45/500 - Recompensa total: 67
# Episodio 46/500 - Recompensa total: -50
# Episodio 47/500 - Recompensa total: -107
# Episodio 48/500 - Recompensa total: -50
# Episodio 49/500 - Recompensa total: 100
# Episodio 50/500 - Recompensa total: -50
# Episodio 51/500 - Recompensa total: 96
# Episodio 52/500 - Recompensa total: 92
# Episodio 53/500 - Recompensa total: -213
# Episodio 54/500 - Recompensa total: -69
# Episodio 55/500 - Recompensa total: 85
# Episodio 56/500 - Recompensa total: -186
# Episodio 57/500 - Recompensa total: 96
# Episodio 58/500 - Recompensa total: -107
# Episodio 59/500 - Recompensa total: -88
# Episodio 60/500 - Recompensa total: -156
# Episodio 61/500 - Recompensa total: 0
# Episodio 62/500 - Recompensa total: 0
# Episodio 63/500 - Recompensa total: -69
# Episodio 64/500 - Recompensa total: 70
# Episodio 65/500 - Recompensa total: -50
# Episodio 66/500 - Recompensa total: -99
# Episodio 67/500 - Recompensa total: -148
# Episodio 68/500 - Recompensa total: -107
# Episodio 69/500 - Recompensa total: 59
# Episodio 70/500 - Recompensa total: 97
# Episodio 71/500 - Recompensa total: -197
# Episodio 72/500 - Recompensa total: 87
# Episodio 73/500 - Recompensa total: 7
# Episodio 74/500 - Recompensa total: 50
# Episodio 75/500 - Recompensa total: -69
# Episodio 76/500 - Recompensa total: -216
# Episodio 77/500 - Recompensa total: -107
# Episodio 78/500 - Recompensa total: 93
# Episodio 79/500 - Recompensa total: -50
# Episodio 80/500 - Recompensa total: -69
# Episodio 81/500 - Recompensa total: 48
# Episodio 82/500 - Recompensa total: 38
# Episodio 83/500 - Recompensa total: -145
# Episodio 84/500 - Recompensa total: 100
# Episodio 85/500 - Recompensa total: 98
# Episodio 86/500 - Recompensa total: -107
# Episodio 87/500 - Recompensa total: 97
# Episodio 88/500 - Recompensa total: -50
# Episodio 89/500 - Recompensa total: -50
# Episodio 90/500 - Recompensa total: 91
# Episodio 91/500 - Recompensa total: -105
# Episodio 92/500 - Recompensa total: -137
# Episodio 93/500 - Recompensa total: 34
# Episodio 94/500 - Recompensa total: 95
# Episodio 95/500 - Recompensa total: -50
# Episodio 96/500 - Recompensa total: -107
# Episodio 97/500 - Recompensa total: -50
# Episodio 98/500 - Recompensa total: 93
# Episodio 99/500 - Recompensa total: -126
# Episodio 100/500 - Recompensa total: -50
# Episodio 101/500 - Recompensa total: 99
# Episodio 102/500 - Recompensa total: 8
# Episodio 103/500 - Recompensa total: 88
# Episodio 104/500 - Recompensa total: -107
# Episodio 105/500 - Recompensa total: -50
# Episodio 106/500 - Recompensa total: -118
# Episodio 107/500 - Recompensa total: -314
# Episodio 108/500 - Recompensa total: 55
# Episodio 109/500 - Recompensa total: -175
# Episodio 110/500 - Recompensa total: -69
# Episodio 111/500 - Recompensa total: 94
# Episodio 112/500 - Recompensa total: -99
# Episodio 113/500 - Recompensa total: -148
# Episodio 114/500 - Recompensa total: -107
# Episodio 115/500 - Recompensa total: -99
# Episodio 116/500 - Recompensa total: -50
# Episodio 117/500 - Recompensa total: -126
# Episodio 118/500 - Recompensa total: 99
# Episodio 119/500 - Recompensa total: -99
# Episodio 120/500 - Recompensa total: 38
# Episodio 121/500 - Recompensa total: -107
# Episodio 122/500 - Recompensa total: -2
# Episodio 123/500 - Recompensa total: 43
# Episodio 124/500 - Recompensa total: -167
# Episodio 125/500 - Recompensa total: -164
# Episodio 126/500 - Recompensa total: 43
# Episodio 127/500 - Recompensa total: 97
# Episodio 128/500 - Recompensa total: 97
# Episodio 129/500 - Recompensa total: -143
# Episodio 130/500 - Recompensa total: 90
# Episodio 131/500 - Recompensa total: 99
# Episodio 132/500 - Recompensa total: -197
# Episodio 133/500 - Recompensa total: -167
# Episodio 134/500 - Recompensa total: -107
# Episodio 135/500 - Recompensa total: 18
# Episodio 136/500 - Recompensa total: -69
# Episodio 137/500 - Recompensa total: -99
# Episodio 138/500 - Recompensa total: -50
# Episodio 139/500 - Recompensa total: -50
# Episodio 140/500 - Recompensa total: 23
# Episodio 141/500 - Recompensa total: 100
# Episodio 142/500 - Recompensa total: 92
# Episodio 143/500 - Recompensa total: 100
# Episodio 144/500 - Recompensa total: -50
# Episodio 145/500 - Recompensa total: 100
# Episodio 146/500 - Recompensa total: -50
# Episodio 147/500 - Recompensa total: 84
# Episodio 148/500 - Recompensa total: 98
# Episodio 149/500 - Recompensa total: -69
# Episodio 150/500 - Recompensa total: -50
# Episodio 151/500 - Recompensa total: 97
# Episodio 152/500 - Recompensa total: 25
# Episodio 153/500 - Recompensa total: 89
# Episodio 154/500 - Recompensa total: 71
# Episodio 155/500 - Recompensa total: -300
# Episodio 156/500 - Recompensa total: 76
# Episodio 157/500 - Recompensa total: -224
# Episodio 158/500 - Recompensa total: -183
# Episodio 159/500 - Recompensa total: 25
# Episodio 160/500 - Recompensa total: 65
# Episodio 161/500 - Recompensa total: -50
# Episodio 162/500 - Recompensa total: -197
# Episodio 163/500 - Recompensa total: 98
# Episodio 164/500 - Recompensa total: -69
# Episodio 165/500 - Recompensa total: 87
# Episodio 166/500 - Recompensa total: 98
# Episodio 167/500 - Recompensa total: 16
# Episodio 168/500 - Recompensa total: -69
# Episodio 169/500 - Recompensa total: 99
# Episodio 170/500 - Recompensa total: -221
# Episodio 171/500 - Recompensa total: -88
# Episodio 172/500 - Recompensa total: 45
# Episodio 173/500 - Recompensa total: -224
# Episodio 174/500 - Recompensa total: 99
# Episodio 175/500 - Recompensa total: 100
# Episodio 176/500 - Recompensa total: -352
# Episodio 177/500 - Recompensa total: 93
# Episodio 178/500 - Recompensa total: -371
# Episodio 179/500 - Recompensa total: -99
# Episodio 180/500 - Recompensa total: 100
# Episodio 181/500 - Recompensa total: -148
# Episodio 182/500 - Recompensa total: -69
# Episodio 183/500 - Recompensa total: -50
# Episodio 184/500 - Recompensa total: 16
# Episodio 185/500 - Recompensa total: -99
# Episodio 186/500 - Recompensa total: -156
# Episodio 187/500 - Recompensa total: -137
# Episodio 188/500 - Recompensa total: -221
# Episodio 189/500 - Recompensa total: -88
# Episodio 190/500 - Recompensa total: -99
# Episodio 191/500 - Recompensa total: -50
# Episodio 192/500 - Recompensa total: -69
# Episodio 193/500 - Recompensa total: -88
# Episodio 194/500 - Recompensa total: -107
# Episodio 195/500 - Recompensa total: -251
# Episodio 196/500 - Recompensa total: 90
# Episodio 197/500 - Recompensa total: -50
# Episodio 198/500 - Recompensa total: -99
# Episodio 199/500 - Recompensa total: -221
# Episodio 200/500 - Recompensa total: -69
# Episodio 201/500 - Recompensa total: 89
# Episodio 202/500 - Recompensa total: -137
# Episodio 203/500 - Recompensa total: -67
# Episodio 204/500 - Recompensa total: -235
# Episodio 205/500 - Recompensa total: -50
# Episodio 206/500 - Recompensa total: -88
# Episodio 207/500 - Recompensa total: -107
# Episodio 208/500 - Recompensa total: 100
# Episodio 209/500 - Recompensa total: -69
# Episodio 210/500 - Recompensa total: 96
# Episodio 211/500 - Recompensa total: -164
# Episodio 212/500 - Recompensa total: -273
# Episodio 213/500 - Recompensa total: -88
# Episodio 214/500 - Recompensa total: 0
# Episodio 215/500 - Recompensa total: 76
# Episodio 216/500 - Recompensa total: 40
# Episodio 217/500 - Recompensa total: 92
# Episodio 218/500 - Recompensa total: -224
# Episodio 219/500 - Recompensa total: -118
# Episodio 220/500 - Recompensa total: 100
# Episodio 221/500 - Recompensa total: 47
# Episodio 222/500 - Recompensa total: -77
# Episodio 223/500 - Recompensa total: -137
# Episodio 224/500 - Recompensa total: 98
# Episodio 225/500 - Recompensa total: -50
# Episodio 226/500 - Recompensa total: -202
# Episodio 227/500 - Recompensa total: -156
# Episodio 228/500 - Recompensa total: -145
# Episodio 229/500 - Recompensa total: 100
# Episodio 230/500 - Recompensa total: 70
# Episodio 231/500 - Recompensa total: -50
# Episodio 232/500 - Recompensa total: -118
# Episodio 233/500 - Recompensa total: -262
# Episodio 234/500 - Recompensa total: -88
# Episodio 235/500 - Recompensa total: 98
# Episodio 236/500 - Recompensa total: -197
# Episodio 237/500 - Recompensa total: 58
# Episodio 238/500 - Recompensa total: -69
# Episodio 239/500 - Recompensa total: 100
# Episodio 240/500 - Recompensa total: -50
# Episodio 241/500 - Recompensa total: -262
# Episodio 242/500 - Recompensa total: -50
# Episodio 243/500 - Recompensa total: 0
# Episodio 244/500 - Recompensa total: -145
# Episodio 245/500 - Recompensa total: -322
# Episodio 246/500 - Recompensa total: 91
# Episodio 247/500 - Recompensa total: -88
# Episodio 248/500 - Recompensa total: 82
# Episodio 249/500 - Recompensa total: -52
# Episodio 250/500 - Recompensa total: 3
# Episodio 251/500 - Recompensa total: -99
# Episodio 252/500 - Recompensa total: 70
# Episodio 253/500 - Recompensa total: 7
# Episodio 254/500 - Recompensa total: 67
# Episodio 255/500 - Recompensa total: 93
# Episodio 256/500 - Recompensa total: -118
# Episodio 257/500 - Recompensa total: 0
# Episodio 258/500 - Recompensa total: -126
# Episodio 259/500 - Recompensa total: -107
# Episodio 260/500 - Recompensa total: -344
# Episodio 261/500 - Recompensa total: -50
# Episodio 262/500 - Recompensa total: -88
# Episodio 263/500 - Recompensa total: -186
# Episodio 264/500 - Recompensa total: 17
# Episodio 265/500 - Recompensa total: -50
# Episodio 266/500 - Recompensa total: 97
# Episodio 267/500 - Recompensa total: 98
# Episodio 268/500 - Recompensa total: 92
# Episodio 269/500 - Recompensa total: -99
# Episodio 270/500 - Recompensa total: -50
# Episodio 271/500 - Recompensa total: -107
# Episodio 272/500 - Recompensa total: -148
# Episodio 273/500 - Recompensa total: 86
# Episodio 274/500 - Recompensa total: -88
# Episodio 275/500 - Recompensa total: 3
# Episodio 276/500 - Recompensa total: 99
# Episodio 277/500 - Recompensa total: 93
# Episodio 278/500 - Recompensa total: -232
# Episodio 279/500 - Recompensa total: -137
# Episodio 280/500 - Recompensa total: -50
# Episodio 281/500 - Recompensa total: -148
# Episodio 282/500 - Recompensa total: -50
# Episodio 283/500 - Recompensa total: -69
# Episodio 284/500 - Recompensa total: -88
# Episodio 285/500 - Recompensa total: -186
# Episodio 286/500 - Recompensa total: -88
# Episodio 287/500 - Recompensa total: -23
# Episodio 288/500 - Recompensa total: -164
# Episodio 289/500 - Recompensa total: -246
# Episodio 290/500 - Recompensa total: -50
# Episodio 291/500 - Recompensa total: -118
# Episodio 292/500 - Recompensa total: 64
# Episodio 293/500 - Recompensa total: -50
# Episodio 294/500 - Recompensa total: -246
# Episodio 295/500 - Recompensa total: -295
# Episodio 296/500 - Recompensa total: 55
# Episodio 297/500 - Recompensa total: -148
# Episodio 298/500 - Recompensa total: -118
# Episodio 299/500 - Recompensa total: 50
# Episodio 300/500 - Recompensa total: -126
# Episodio 301/500 - Recompensa total: -69
# Episodio 302/500 - Recompensa total: 99
# Episodio 303/500 - Recompensa total: -167
# Episodio 304/500 - Recompensa total: 98
# Episodio 305/500 - Recompensa total: -50
# Episodio 306/500 - Recompensa total: -137
# Episodio 307/500 - Recompensa total: 62
# Episodio 308/500 - Recompensa total: -50
# Episodio 309/500 - Recompensa total: -194
# Episodio 310/500 - Recompensa total: 100
# Episodio 311/500 - Recompensa total: 15
# Episodio 312/500 - Recompensa total: -137
# Episodio 313/500 - Recompensa total: 98
# Episodio 314/500 - Recompensa total: 95
# Episodio 315/500 - Recompensa total: -186
# Episodio 316/500 - Recompensa total: -88
# Episodio 317/500 - Recompensa total: 19
# Episodio 318/500 - Recompensa total: -50
# Episodio 319/500 - Recompensa total: -50
# Episodio 320/500 - Recompensa total: 0
# Episodio 321/500 - Recompensa total: -137
# Episodio 322/500 - Recompensa total: -69
# Episodio 323/500 - Recompensa total: -186
# Episodio 324/500 - Recompensa total: 36
# Episodio 325/500 - Recompensa total: 100
# Episodio 326/500 - Recompensa total: -50
# Episodio 327/500 - Recompensa total: -183
# Episodio 328/500 - Recompensa total: -88
# Episodio 329/500 - Recompensa total: 100
# Episodio 330/500 - Recompensa total: 96
# Episodio 331/500 - Recompensa total: 99
# Episodio 332/500 - Recompensa total: 97
# Episodio 333/500 - Recompensa total: 0
# Episodio 334/500 - Recompensa total: -164
# Episodio 335/500 - Recompensa total: -88
# Episodio 336/500 - Recompensa total: -107
# Episodio 337/500 - Recompensa total: 60
# Episodio 338/500 - Recompensa total: 0
# Episodio 339/500 - Recompensa total: -88
# Episodio 340/500 - Recompensa total: -88
# Episodio 341/500 - Recompensa total: -352
# Episodio 342/500 - Recompensa total: 99
# Episodio 343/500 - Recompensa total: -69
# Episodio 344/500 - Recompensa total: 12
# Episodio 345/500 - Recompensa total: -216
# Episodio 346/500 - Recompensa total: -126
# Episodio 347/500 - Recompensa total: -27
# Episodio 348/500 - Recompensa total: 0
# Episodio 349/500 - Recompensa total: 94
# Episodio 350/500 - Recompensa total: 18
# Episodio 351/500 - Recompensa total: -69
# Episodio 352/500 - Recompensa total: -145
# Episodio 353/500 - Recompensa total: 0
# Episodio 354/500 - Recompensa total: -50
# Episodio 355/500 - Recompensa total: -50
# Episodio 356/500 - Recompensa total: 79
# Episodio 357/500 - Recompensa total: 99
# Episodio 358/500 - Recompensa total: -80
# Episodio 359/500 - Recompensa total: -314
# Episodio 360/500 - Recompensa total: -69
# Episodio 361/500 - Recompensa total: -50
# Episodio 362/500 - Recompensa total: -69
# Episodio 363/500 - Recompensa total: -164
# Episodio 364/500 - Recompensa total: 96
# Episodio 365/500 - Recompensa total: -50
# Episodio 366/500 - Recompensa total: -145
# Episodio 367/500 - Recompensa total: -137
# Episodio 368/500 - Recompensa total: -148
# Episodio 369/500 - Recompensa total: 52
# Episodio 370/500 - Recompensa total: 100
# Episodio 371/500 - Recompensa total: 77
# Episodio 372/500 - Recompensa total: -148
# Episodio 373/500 - Recompensa total: -156
# Episodio 374/500 - Recompensa total: 99
# Episodio 375/500 - Recompensa total: -69
# Episodio 376/500 - Recompensa total: -107
# Episodio 377/500 - Recompensa total: 0
# Episodio 378/500 - Recompensa total: 100
# Episodio 379/500 - Recompensa total: -50
# Episodio 380/500 - Recompensa total: 100
# Episodio 381/500 - Recompensa total: -224
# Episodio 382/500 - Recompensa total: -118
# Episodio 383/500 - Recompensa total: -107
# Episodio 384/500 - Recompensa total: 44
# Episodio 385/500 - Recompensa total: -88
# Episodio 386/500 - Recompensa total: -197
# Episodio 387/500 - Recompensa total: 100
# Episodio 388/500 - Recompensa total: -69
# Episodio 389/500 - Recompensa total: 60
# Episodio 390/500 - Recompensa total: 84
# Episodio 391/500 - Recompensa total: 88
# Episodio 392/500 - Recompensa total: 0
# Episodio 393/500 - Recompensa total: 98
# Episodio 394/500 - Recompensa total: -145
# Episodio 395/500 - Recompensa total: -295
# Episodio 396/500 - Recompensa total: 70
# Episodio 397/500 - Recompensa total: -213
# Episodio 398/500 - Recompensa total: -88
# Episodio 399/500 - Recompensa total: -50
# Episodio 400/500 - Recompensa total: 95
# Episodio 401/500 - Recompensa total: 53
# Episodio 402/500 - Recompensa total: 100
# Episodio 403/500 - Recompensa total: -15
# Episodio 404/500 - Recompensa total: -126
# Episodio 405/500 - Recompensa total: -69
# Episodio 406/500 - Recompensa total: 16
# Episodio 407/500 - Recompensa total: -107
# Episodio 408/500 - Recompensa total: -243
# Episodio 409/500 - Recompensa total: -55
# Episodio 410/500 - Recompensa total: -23
# Episodio 411/500 - Recompensa total: 61
# Episodio 412/500 - Recompensa total: -88
# Episodio 413/500 - Recompensa total: 94
# Episodio 414/500 - Recompensa total: -88
# Episodio 415/500 - Recompensa total: -148
# Episodio 416/500 - Recompensa total: -50
# Episodio 417/500 - Recompensa total: 0
# Episodio 418/500 - Recompensa total: -273
# Episodio 419/500 - Recompensa total: 99
# Episodio 420/500 - Recompensa total: 99
# Episodio 421/500 - Recompensa total: 40
# Episodio 422/500 - Recompensa total: -3
# Episodio 423/500 - Recompensa total: -183
# Episodio 424/500 - Recompensa total: 45
# Episodio 425/500 - Recompensa total: -50
# Episodio 426/500 - Recompensa total: -99
# Episodio 427/500 - Recompensa total: -254
# Episodio 428/500 - Recompensa total: -33
# Episodio 429/500 - Recompensa total: -145
# Episodio 430/500 - Recompensa total: -50
# Episodio 431/500 - Recompensa total: 91
# Episodio 432/500 - Recompensa total: -22
# Episodio 433/500 - Recompensa total: -126
# Episodio 434/500 - Recompensa total: -107
# Episodio 435/500 - Recompensa total: 85
# Episodio 436/500 - Recompensa total: 99
# Episodio 437/500 - Recompensa total: -11
# Episodio 438/500 - Recompensa total: 98
# Episodio 439/500 - Recompensa total: 30
# Episodio 440/500 - Recompensa total: 90
# Episodio 441/500 - Recompensa total: -85
# Episodio 442/500 - Recompensa total: 84
# Episodio 443/500 - Recompensa total: 97
# Episodio 444/500 - Recompensa total: -88
# Episodio 445/500 - Recompensa total: -164
# Episodio 446/500 - Recompensa total: 55
# Episodio 447/500 - Recompensa total: -156
# Episodio 448/500 - Recompensa total: 66
# Episodio 449/500 - Recompensa total: -311
# Episodio 450/500 - Recompensa total: -167
# Episodio 451/500 - Recompensa total: -12
# Episodio 452/500 - Recompensa total: 100
# Episodio 453/500 - Recompensa total: 96
# Episodio 454/500 - Recompensa total: -50
# Episodio 455/500 - Recompensa total: -88
# Episodio 456/500 - Recompensa total: 74
# Episodio 457/500 - Recompensa total: 33
# Episodio 458/500 - Recompensa total: -50
# Episodio 459/500 - Recompensa total: 99
# Episodio 460/500 - Recompensa total: 95
# Episodio 461/500 - Recompensa total: 94
# Episodio 462/500 - Recompensa total: 22
# Episodio 463/500 - Recompensa total: 44
# Episodio 464/500 - Recompensa total: 99
# Episodio 465/500 - Recompensa total: 58
# Episodio 466/500 - Recompensa total: -69
# Episodio 467/500 - Recompensa total: 27
# Episodio 468/500 - Recompensa total: 75
# Episodio 469/500 - Recompensa total: -197
# Episodio 470/500 - Recompensa total: -300
# Episodio 471/500 - Recompensa total: -18
# Episodio 472/500 - Recompensa total: -69
# Episodio 473/500 - Recompensa total: -69
# Episodio 474/500 - Recompensa total: 82
# Episodio 475/500 - Recompensa total: 91
# Episodio 476/500 - Recompensa total: -88
# Episodio 477/500 - Recompensa total: 34
# Episodio 478/500 - Recompensa total: -88
# Episodio 479/500 - Recompensa total: 60
# Episodio 480/500 - Recompensa total: -99
# Episodio 481/500 - Recompensa total: -167
# Episodio 482/500 - Recompensa total: 92
# Episodio 483/500 - Recompensa total: 67
# Episodio 484/500 - Recompensa total: -235
# Episodio 485/500 - Recompensa total: -50
# Episodio 486/500 - Recompensa total: 9
# Episodio 487/500 - Recompensa total: -273
# Episodio 488/500 - Recompensa total: 0
# Episodio 489/500 - Recompensa total: -52
# Episodio 490/500 - Recompensa total: 94
# Episodio 491/500 - Recompensa total: -145
# Episodio 492/500 - Recompensa total: -50
# Episodio 493/500 - Recompensa total: 54
# Episodio 494/500 - Recompensa total: 88
# Episodio 495/500 - Recompensa total: -69
# Episodio 496/500 - Recompensa total: 49
# Episodio 497/500 - Recompensa total: -69
# Episodio 498/500 - Recompensa total: -50
# Episodio 499/500 - Recompensa total: -371
# Episodio 500/500 - Recompensa total: -205

# %%
# Imprimir la tabla Q después del entrenamiento
def imprimir_Q():
    for i in range(tamaño[0]):
        for j in range(tamaño[1]):
            print(f"Estado ({i}, {j}): {Q[i, j]}")

imprimir_Q()
# Out:
# Estado (0, 0): [  2.7535697   -7.65278755  -8.32552483 -11.29148882]
# Estado (0, 1): [ -6.04137703 -10.85239744  -6.59955828  -1.92874338]
# Estado (0, 2): [-12.84848927  -6.69899875  -4.98062952  -1.23067979]
# Estado (0, 3): [-10.90962899  -7.66201319  -7.01429063  -5.35790013]
# Estado (0, 4): [-5.15292084 -5.94409333 -7.10552633 -4.78815263]
# Estado (1, 0): [-6.51943109 -6.79858434 -0.35150916 -8.57406476]
# Estado (1, 1): [-0.59827264 -3.25817    -5.7631265  -1.13350376]
# Estado (1, 2): [-3.96990265 -2.1682589  -2.19686864 -1.03185322]
# Estado (1, 3): [-3.62786015 -0.91753539 -6.53382871 -5.60060277]
# Estado (1, 4): [-4.39845571 -4.461936   -5.97860264 -8.32230636]
# Estado (2, 0): [-6.12989454 -4.58847192  3.80413024  1.59460844]
# Estado (2, 1): [-3.67492995  0.62745213 -3.10499493 -4.98487745]
# Estado (2, 2): [-1.54024324 -3.13608759 -2.50083301 -3.27730115]
# Estado (2, 3): [-11.22626373  -1.39098606  -3.31068098  -4.07659252]
# Estado (2, 4): [-13.51429286  -2.99018783  -0.49601529  -5.51692476]
# Estado (3, 0): [-8.40686464 -7.54423229  1.71215061 -7.25971029]
# Estado (3, 1): [-5.7547522  -6.82637389 -6.28955212 -5.97640004]
# Estado (3, 2): [-7.00219126 -5.42443441 -1.31805318 -7.63224464]
# Estado (3, 3): [-11.47451044  -5.39223339  -7.50081917  -3.66467198]
# Estado (3, 4): [ -8.2492959   -6.20675256 -11.54285314  -5.15972274]
# Estado (4, 0): [ -4.52870986  -5.68905801  -0.88006633 -12.29657634]
# Estado (4, 1): [-2.81934595 -6.93984261 -1.9929822  -4.07718893]
# Estado (4, 2): [-3.8627015  -2.20763468 -6.33684075 -9.10679156]
# Estado (4, 3): [-0.41045231 -4.2949687  -5.29067757 -7.42152707]
# Estado (4, 4): [-4.87146086 -8.85919812  1.34646823 -3.59844671]

# %% [markdown]
# # Prueba de explotación para 100 episodios

# %%
import random
import numpy as np

# Tamaño del entorno y la tabla Q entrenada
tamaño = (5, 5)
acciones = [(0, 1), (0, -1), (-1, 0), (1, 0)]  # Arriba, Abajo, Izquierda, Derecha

# Definir posiciones dinámicas: trampa, guardia, salida
def generar_posiciones_dinamicas():
    trampa = (random.randint(0, tamaño[0]-1), random.randint(0, tamaño[1]-1))
    guardia = (random.randint(0, tamaño[0]-1), random.randint(0, tamaño[1]-1))
    while trampa == guardia:  # Asegurarse de que no haya superposición
        guardia = (random.randint(0, tamaño[0]-1), random.randint(0, tamaño[1]-1))
    salida = (random.randint(0, tamaño[0]-1), random.randint(0, tamaño[1]-1))
    return trampa, guardia, salida

# Función para obtener recompensa dinámica
def obtener_recompensa(estado, guardia, trampa, salida):
    if estado == salida:
        return 100  # Recompensa por llegar a la salida
    elif estado == trampa:
        return -50  # Penalización por caer en la trampa
    elif estado == guardia:
        return -20  # Penalización por encontrarse con el guardia
    else:
        return -1  # Penalización por moverse a cualquier otro estado

# Función para mover al guardia
def mover_guardia(guardia):
    mov = random.choice([(0, 1), (0, -1), (1, 0), (-1, 0)])  # Movimiento aleatorio
    nueva_pos = (guardia[0] + mov[0], guardia[1] + mov[1])
    nueva_pos = (max(0, min(nueva_pos[0], tamaño[0]-1)), max(0, min(nueva_pos[1], tamaño[1]-1)))
    return nueva_pos

# Función para probar el agente (sin exploración)
def probar_agente_explotacion(Q, n_episodios=100):
    for episodio in range(n_episodios):
        trampa, guardia, salida = generar_posiciones_dinamicas()
        estado = (random.randint(0, tamaño[0]-1), random.randint(0, tamaño[1]-1))  # Estado inicial aleatorio

        atrapado = False
        pasos = 0

        while estado != salida and pasos < 50:  # Limitar pasos para evitar bucles infinitos
            # Seleccionar acción con la mayor Q (explotación)
            accion = np.argmax(Q[estado[0], estado[1]])
            nuevo_estado = (estado[0] + acciones[accion][0], estado[1] + acciones[accion][1])

            # Asegurarse de que el nuevo estado esté dentro de los límites del entorno
            nuevo_estado = (max(0, min(nuevo_estado[0], tamaño[0]-1)), max(0, min(nuevo_estado[1], tamaño[1]-1)))

            # Obtener la recompensa dinámica
            recompensa = obtener_recompensa(nuevo_estado, guardia, trampa, salida)

            # Mover al guardia
            guardia = mover_guardia(guardia)

            # Verificar si el agente ha sido atrapado
            if nuevo_estado == guardia:
                atrapado = True
                break  # El agente es atrapado, termina el episodio

            # Actualizar el estado
            estado = nuevo_estado
            pasos += 1

        # Mostrar el resultado del episodio
        if atrapado:
            print(f"Episodio {episodio + 1}/{n_episodios} - El agente fue atrapado")
        else:
            print(f"Episodio {episodio + 1}/{n_episodios} - El agente llegó a la salida")

# Probar el agente con explotación
probar_agente_explotacion(Q, n_episodios=100)
# Out:
# Episodio 1/100 - El agente llegó a la salida
# Episodio 2/100 - El agente fue atrapado
# Episodio 3/100 - El agente fue atrapado
# Episodio 4/100 - El agente llegó a la salida
# Episodio 5/100 - El agente llegó a la salida
# Episodio 6/100 - El agente fue atrapado
# Episodio 7/100 - El agente llegó a la salida
# Episodio 8/100 - El agente fue atrapado
# Episodio 9/100 - El agente fue atrapado
# Episodio 10/100 - El agente fue atrapado
# Episodio 11/100 - El agente llegó a la salida
# Episodio 12/100 - El agente llegó a la salida
# Episodio 13/100 - El agente llegó a la salida
# Episodio 14/100 - El agente llegó a la salida
# Episodio 15/100 - El agente fue atrapado
# Episodio 16/100 - El agente llegó a la salida
# Episodio 17/100 - El agente fue atrapado
# Episodio 18/100 - El agente fue atrapado
# Episodio 19/100 - El agente fue atrapado
# Episodio 20/100 - El agente fue atrapado
# Episodio 21/100 - El agente fue atrapado
# Episodio 22/100 - El agente llegó a la salida
# Episodio 23/100 - El agente llegó a la salida
# Episodio 24/100 - El agente llegó a la salida
# Episodio 25/100 - El agente llegó a la salida
# Episodio 26/100 - El agente fue atrapado
# Episodio 27/100 - El agente fue atrapado
# Episodio 28/100 - El agente fue atrapado
# Episodio 29/100 - El agente fue atrapado
# Episodio 30/100 - El agente llegó a la salida
# Episodio 31/100 - El agente fue atrapado
# Episodio 32/100 - El agente llegó a la salida
# Episodio 33/100 - El agente llegó a la salida
# Episodio 34/100 - El agente fue atrapado
# Episodio 35/100 - El agente llegó a la salida
# Episodio 36/100 - El agente fue atrapado
# Episodio 37/100 - El agente fue atrapado
# Episodio 38/100 - El agente llegó a la salida
# Episodio 39/100 - El agente llegó a la salida
# Episodio 40/100 - El agente fue atrapado
# Episodio 41/100 - El agente llegó a la salida
# Episodio 42/100 - El agente fue atrapado
# Episodio 43/100 - El agente llegó a la salida
# Episodio 44/100 - El agente llegó a la salida
# Episodio 45/100 - El agente llegó a la salida
# Episodio 46/100 - El agente llegó a la salida
# Episodio 47/100 - El agente fue atrapado
# Episodio 48/100 - El agente fue atrapado
# Episodio 49/100 - El agente fue atrapado
# Episodio 50/100 - El agente llegó a la salida
# Episodio 51/100 - El agente fue atrapado
# Episodio 52/100 - El agente llegó a la salida
# Episodio 53/100 - El agente fue atrapado
# Episodio 54/100 - El agente llegó a la salida
# Episodio 55/100 - El agente fue atrapado
# Episodio 56/100 - El agente fue atrapado
# Episodio 57/100 - El agente llegó a la salida
# Episodio 58/100 - El agente llegó a la salida
# Episodio 59/100 - El agente llegó a la salida
# Episodio 60/100 - El agente fue atrapado
# Episodio 61/100 - El agente fue atrapado
# Episodio 62/100 - El agente fue atrapado
# Episodio 63/100 - El agente llegó a la salida
# Episodio 64/100 - El agente fue atrapado
# Episodio 65/100 - El agente fue atrapado
# Episodio 66/100 - El agente llegó a la salida
# Episodio 67/100 - El agente llegó a la salida
# Episodio 68/100 - El agente llegó a la salida
# Episodio 69/100 - El agente fue atrapado
# Episodio 70/100 - El agente fue atrapado
# Episodio 71/100 - El agente fue atrapado
# Episodio 72/100 - El agente fue atrapado
# Episodio 73/100 - El agente llegó a la salida
# Episodio 74/100 - El agente fue atrapado
# Episodio 75/100 - El agente fue atrapado
# Episodio 76/100 - El agente fue atrapado
# Episodio 77/100 - El agente llegó a la salida
# Episodio 78/100 - El agente fue atrapado
# Episodio 79/100 - El agente llegó a la salida
# Episodio 80/100 - El agente fue atrapado
# Episodio 81/100 - El agente fue atrapado
# Episodio 82/100 - El agente llegó a la salida
# Episodio 83/100 - El agente llegó a la salida
# Episodio 84/100 - El agente fue atrapado
# Episodio 85/100 - El agente fue atrapado
# Episodio 86/100 - El agente llegó a la salida
# Episodio 87/100 - El agente llegó a la salida
# Episodio 88/100 - El agente llegó a la salida
# Episodio 89/100 - El agente fue atrapado
# Episodio 90/100 - El agente llegó a la salida
# Episodio 91/100 - El agente fue atrapado
# Episodio 92/100 - El agente fue atrapado
# Episodio 93/100 - El agente llegó a la salida
# Episodio 94/100 - El agente fue atrapado
# Episodio 95/100 - El agente fue atrapado
# Episodio 96/100 - El agente fue atrapado
# Episodio 97/100 - El agente fue atrapado
# Episodio 98/100 - El agente llegó a la salida
# Episodio 99/100 - El agente fue atrapado
# Episodio 100/100 - El agente llegó a la salida
